# %%
print("Suprise mother fucker" )
# Out:
# Suprise mother fucker

# %%
print("hello  hırre kare ")
# Out:
# hello  hırre kare

# %% [markdown]
# #merhab

# %% [markdown]
# ## Merhaba dünya

# %% [markdown]
# #merhaba

# %%
import numpy as np

# %%
a=np.array([1,2,3,4])
b=np.array([2,3,4,5])

# %%
a*b
# Out:
# array([ 2,  6, 12, 20])

# %%
ab=[]
a=[1,2,3,4]
b=[2,3,4,5]

# %%
for i in range( 0,len(a)):
    ab.append(a[i]*b[i])

ab
# Out:
# [2, 6, 12, 20]
